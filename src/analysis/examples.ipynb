# %% [markdown]
# # Examples
#
# with some unscientific performance timings

# %%
# %load_ext watermark

# %%
# %watermark -m -v -p duckdb
# Out:
# Python implementation: CPython
# Python version       : 3.10.2
# IPython version      : 8.0.1
#
# duckdb: 0.3.3.dev1397
#
# Compiler    : Clang 12.0.5 (clang-1205.0.22.9)
# OS          : Darwin
# Release     : 21.4.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 8
# Architecture: 64bit

# %%
from pathlib import Path
import time

import duckdb
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 40)

sns.set_style('whitegrid')

# %%
QUERY_DIR = Path.cwd() / 'queries'

# %%
def load_query(query_name: str, show: bool = False) -> str:
    fname = QUERY_DIR / query_name
    fname = fname.with_suffix('.sql') if not query_name.endswith('sql') else fname
    
    with open(fname) as f:
        query = f.read()
    
    if show:
        print(query)

    return query

# %%
conn = duckdb.connect('../lahnman.duckdb')

# %% [markdown]
# ## Longest tenure by team
#
# Which players had the longest tenure for each franchise? For this query we are only going to consider currently active franchises.

# %%
longest_tenure_query = load_query('longest_tenure_by_team', show=True)
# Out:
# WITH player_tenures AS (
# SELECT
#     a.playerID
#     ,p.nameFirst
#     ,p.nameLast
#     ,t.franchID
#     ,t.name as team_name
#     ,MIN(a.yearID) as first_year
#     ,MAX(a.yearID) as last_year
#     ,COUNT(DISTINCT a.yearID) as years
#     ,DENSE_RANK() OVER (PARTITION BY t.franchID ORDER BY COUNT(DISTINCT a.yearID) DESC) as rank
# FROM appearances a
# JOIN people p
#     ON a.playerID = p.playerID
# JOIN teams t
#     ON t.teamID = a.teamID
#     AND t.yearID = a.yearID
# JOIN teamsfranchises tf
#     ON t.franchID = tf.franchID
#     AND t.name = tf.franchName
# WHERE
#     tf.active = 'Y'
# GROUP BY
#     a.playerID
#     ,p.nameFirst
#     ,p.nameLast
#     ,t.franchID
#     ,t.name
# )
#
# SELECT
#     playerID
#     ,nameFirst
#     ,nameLast
#     ,franchID
#     ,team_name
#     ,first_year
#     ,last_year
#     ,years
# FROM player_tenures
# WHERE
#     rank = 1
# ORDER BY
#     franchID
#     ,years DESC

# %%
start = time.perf_counter()
longest_tenure = conn.execute(longest_tenure_query).df()
print(f'query time: {time.perf_counter() - start:.3}')

# make sure all teams are represented
current_distinct_teams = conn.execute("SELECT DISTINCT franchID FROM teamsfranchises WHERE active = 'Y'").fetchall()
assert len(current_distinct_teams) == len(longest_tenure['franchID'].unique())

longest_tenure
# Out:
# query time: 0.0749
#      playerID nameFirst     nameLast franchID                      team_name  \
# 0   weaveje02     Jered       Weaver      ANA  Los Angeles Angels of Anaheim
# 1   troutmi01      Mike        Trout      ANA  Los Angeles Angels of Anaheim
# 2   montemi01    Miguel      Montero      ARI           Arizona Diamondbacks
# 3   smoltjo01      John       Smoltz      ATL                 Atlanta Braves
# 4   robinbr01    Brooks     Robinson      BAL              Baltimore Orioles
# 5   yastrca01      Carl  Yastrzemski      BOS                 Boston Red Sox
# 6   cavarph01      Phil   Cavarretta      CHC                   Chicago Cubs
# 7   lyonste01       Ted        Lyons      CHW              Chicago White Sox
# 8    rosepe01      Pete         Rose      CIN                Cincinnati Reds
# 9   conceda01      Dave   Concepcion      CIN                Cincinnati Reds
# 10  larkiba01     Barry       Larkin      CIN                Cincinnati Reds
# 11  hardeme01       Mel       Harder      CLE              Cleveland Indians
# 12  heltoto01      Todd       Helton      COL               Colorado Rockies
# 13   cobbty01        Ty         Cobb      DET                 Detroit Tigers
# 14  kalinal01        Al       Kaline      DET                 Detroit Tigers
# 15  castilu01      Luis     Castillo      FLA                Florida Marlins
# 16  biggicr01     Craig       Biggio      HOU                 Houston Astros
# 17  brettge01    George        Brett      KCR             Kansas City Royals
# 18  russebi01      Bill      Russell      LAD            Los Angeles Dodgers
# 19  yountro01     Robin        Yount      MIL              Milwaukee Brewers
# 20  olivato01      Tony        Oliva      MIN                Minnesota Twins
# 21  mauerjo01       Joe        Mauer      MIN                Minnesota Twins
# 22  kraneed01        Ed    Kranepool      NYM                  New York Mets
# 23  jeterde01     Derek        Jeter      NYY               New York Yankees
# 24  henderi01    Rickey    Henderson      OAK              Oakland Athletics
# 25  schmimi01      Mike      Schmidt      PHI          Philadelphia Phillies
# 26  stargwi01    Willie     Stargell      PIT             Pittsburgh Pirates
# 27  gwynnto01      Tony        Gwynn      SDP               San Diego Padres
# 28  martied01     Edgar     Martinez      SEA               Seattle Mariners
# 29  mccovwi01    Willie      McCovey      SFG           San Francisco Giants
# 30  musiast01      Stan       Musial      STL            St. Louis Cardinals
# 31  longoev01      Evan     Longoria      TBD                 Tampa Bay Rays
# 32  gonzaju03      Juan     Gonzalez      TEX                  Texas Rangers
# 33  rodriiv01      Ivan    Rodriguez      TEX                  Texas Rangers
# 34  youngmi02   Michael        Young      TEX                  Texas Rangers
# 35  stiebda01      Dave        Stieb      TOR              Toronto Blue Jays
# 36  zimmery01      Ryan    Zimmerman      WSN           Washington Nationals
#
#     first_year  last_year  years
# 0         2006       2016     11
# 1         2011       2021     11
# 2         2006       2014      9
# 3         1988       2008     20
# 4         1955       1977     23
# 5         1961       1983     23
# 6         1934       1953     20
# 7         1923       1946     21
# 8         1963       1986     19
# 9         1970       1988     19
# 10        1986       2004     19
# 11        1928       1947     20
# 12        1997       2013     17
# 13        1905       1926     22
# 14        1953       1974     22
# 15        1996       2005     10
# 16        1988       2007     20
# 17        1973       1993     21
# 18        1969       1986     18
# 19        1974       1993     20
# 20        1962       1976     15
# 21        2004       2018     15
# 22        1962       1979     18
# 23        1995       2014     20
# 24        1979       1998     14
# 25        1972       1989     18
# 26        1962       1982     21
# 27        1982       2001     20
# 28        1987       2004     18
# 29        1959       1980     19
# 30        1941       1963     22
# 31        2008       2017     10
# 32        1989       2003     13
# 33        1991       2009     13
# 34        2000       2012     13
# 35        1979       1998     15
# 36        2005       2021     16
